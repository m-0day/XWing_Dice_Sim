# %%
import plotly.graph_objects as go 
import pandas as pd
import numpy as np
from ipywidgets import widgets

df = pd.read_csv('Dice_Rolls.csv')
df = df.drop(['Unnamed: 0'], axis = 1)
str_cols = ['Phr', 'pe', 'ph']
for col in str_cols:
    df[col] = df[col].str.strip("[]")

i = 0
for i in range(len(df)):
    if i >= 24:
        print(round(i/599, 3)*100, "% done")
    df['Phr'][i] = " ".join(df['Phr'][i].split()) #this is so ridiculous
    df['Phr'][i] = [float(s) for s in df['Phr'][i].split(" ")]
    df['pe'][i] = " ".join(df['pe'][i].split())
    df['pe'][i] = [float(s) for s in df['pe'][i].split(" ")]
    df['ph'][i] = " ".join(df['ph'][i].split())
    df['ph'][i] = [float(s) for s in df['ph'][i].split(" ")]
    
df.columns

f = go.FigureWidget()
# Out:
# C:\Users\CM\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\CM\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\CM\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\CM\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\CM\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\CM\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 4.0 % done
# 4.2 % done
# 4.3 % done
# 4.5 % done
# 4.7 % done
# 4.8 % done
# 5.0 % done
# 5.2 % done
# 5.3 % done
# 5.5 % done
# 5.7 % done
# 5.800000000000001 % done
# 6.0 % done
# 6.2 % done
# 6.3 % done
# 6.5 % done
# 6.7 % done
# 6.800000000000001 % done
# 7.000000000000001 % done
# 7.199999999999999 % done
# 7.3 % done
# 7.5 % done
# 7.7 % done
# 7.8 % done
# 8.0 % done
# 8.200000000000001 % done
# 8.3 % done
# 8.5 % done
# 8.7 % done
# 8.799999999999999 % done
# 9.0 % done
# 9.2 % done
# 9.3 % done
# 9.5 % done
# 9.700000000000001 % done
# 9.8 % done
# 10.0 % done
# 10.2 % done
# 10.4 % done
# 10.5 % done
# 10.7 % done
# 10.9 % done
# 11.0 % done
# 11.200000000000001 % done
# 11.4 % done
# 11.5 % done
# 11.700000000000001 % done
# 11.899999999999999 % done
# 12.0 % done
# 12.2 % done
# 12.4 % done
# 12.5 % done
# 12.7 % done
# 12.9 % done
# 13.0 % done
# 13.200000000000001 % done
# 13.4 % done
# 13.5 % done
# 13.700000000000001 % done
# 13.900000000000002 % done
# 14.000000000000002 % done
# 14.2 % done
# 14.399999999999999 % done
# 14.499999999999998 % done
# 14.7 % done
# 14.899999999999999 % done
# 15.0 % done
# 15.2 % done
# 15.4 % done
# 15.5 % done
# 15.7 % done
# 15.9 % done
# 16.0 % done
# 16.2 % done
# 16.400000000000002 % done
# 16.5 % done
# 16.7 % done
# 16.900000000000002 % done
# 17.0 % done
# 17.2 % done
# 17.4 % done
# 17.5 % done
# 17.7 % done
# 17.9 % done
# 18.0 % done
# 18.2 % done
# 18.4 % done
# 18.5 % done
# 18.7 % done
# 18.9 % done
# 19.0 % done
# 19.2 % done
# 19.400000000000002 % done
# 19.5 % done
# 19.7 % done
# 19.900000000000002 % done
# 20.0 % done
# 20.200000000000003 % done
# 20.4 % done
# 20.5 % done
# 20.7 % done
# 20.9 % done
# 21.0 % done
# 21.2 % done
# 21.4 % done
# 21.5 % done
# 21.7 % done
# 21.9 % done
# 22.0 % done
# 22.2 % done
# 22.400000000000002 % done
# 22.5 % done
# 22.7 % done
# 22.900000000000002 % done
# 23.0 % done
# 23.200000000000003 % done
# 23.400000000000002 % done
# 23.5 % done
# 23.7 % done
# 23.9 % done
# 24.0 % done
# 24.2 % done
# 24.4 % done
# 24.5 % done
# 24.7 % done
# 24.9 % done
# 25.0 % done
# 25.2 % done
# 25.4 % done
# 25.5 % done
# 25.7 % done
# 25.900000000000002 % done
# 26.0 % done
# 26.200000000000003 % done
# 26.400000000000002 % done
# 26.5 % done
# 26.700000000000003 % done
# 26.900000000000002 % done
# 27.0 % done
# 27.200000000000003 % done
# 27.400000000000002 % done
# 27.500000000000004 % done
# 27.700000000000003 % done
# 27.900000000000002 % done
# 28.000000000000004 % done
# 28.199999999999996 % done
# 28.4 % done
# 28.499999999999996 % done
# 28.7 % done
# 28.9 % done
# 28.999999999999996 % done
# 29.2 % done
# 29.4 % done
# 29.5 % done
# 29.7 % done
# 29.9 % done
# 30.099999999999998 % done
# 30.2 % done
# 30.4 % done
# 30.599999999999998 % done
# 30.7 % done
# 30.9 % done
# 31.1 % done
# 31.2 % done
# 31.4 % done
# 31.6 % done
# 31.7 % done
# 31.900000000000002 % done
# 32.1 % done
# 32.2 % done
# 32.4 % done
# 32.6 % done
# 32.7 % done
# 32.9 % done
# 33.1 % done
# 33.2 % done
# 33.4 % done
# 33.6 % done
# 33.7 % done
# 33.900000000000006 % done
# 34.1 % done
# 34.2 % done
# 34.4 % done
# 34.599999999999994 % done
# 34.699999999999996 % done
# 34.9 % done
# 35.099999999999994 % done
# 35.199999999999996 % done
# 35.4 % done
# 35.6 % done
# 35.699999999999996 % done
# 35.9 % done
# 36.1 % done
# 36.199999999999996 % done
# 36.4 % done
# 36.6 % done
# 36.7 % done
# 36.9 % done
# 37.1 % done
# 37.2 % done
# 37.4 % done
# 37.6 % done
# 37.7 % done
# 37.9 % done
# 38.1 % done
# 38.2 % done
# 38.4 % done
# 38.6 % done
# 38.7 % done
# 38.9 % done
# 39.1 % done
# 39.2 % done
# 39.4 % done
# 39.6 % done
# 39.7 % done
# 39.900000000000006 % done
# 40.1 % done
# 40.2 % done
# 40.400000000000006 % done
# 40.6 % done
# 40.699999999999996 % done
# 40.9 % done
# 41.099999999999994 % done
# 41.199999999999996 % done
# 41.4 % done
# 41.6 % done
# 41.699999999999996 % done
# 41.9 % done
# 42.1 % done
# 42.199999999999996 % done
# 42.4 % done
# 42.6 % done
# 42.699999999999996 % done
# 42.9 % done
# 43.1 % done
# 43.2 % done
# 43.4 % done
# 43.6 % done
# 43.7 % done
# 43.9 % done
# 44.1 % done
# 44.2 % done
# 44.4 % done
# 44.6 % done
# 44.7 % done
# 44.9 % done
# 45.1 % done
# 45.2 % done
# 45.4 % done
# 45.6 % done
# 45.7 % done
# 45.9 % done
# 46.1 % done
# 46.2 % done
# 46.400000000000006 % done
# 46.6 % done
# 46.7 % done
# 46.9 % done
# 47.099999999999994 % done
# 47.199999999999996 % done
# 47.4 % done
# 47.599999999999994 % done
# 47.699999999999996 % done
# 47.9 % done
# 48.1 % done
# 48.199999999999996 % done
# 48.4 % done
# 48.6 % done
# 48.699999999999996 % done
# 48.9 % done
# 49.1 % done
# 49.2 % done
# 49.4 % done
# 49.6 % done
# 49.7 % done
# 49.9 % done
# 50.1 % done
# 50.3 % done
# 50.4 % done
# 50.6 % done
# 50.8 % done
# 50.9 % done
# 51.1 % done
# 51.300000000000004 % done
# 51.4 % done
# 51.6 % done
# 51.800000000000004 % done
# 51.9 % done
# 52.1 % done
# 52.300000000000004 % done
# 52.400000000000006 % done
# 52.6 % done
# 52.800000000000004 % done
# 52.900000000000006 % done
# 53.1 % done
# 53.300000000000004 % done
# 53.400000000000006 % done
# 53.6 % done
# 53.800000000000004 % done
# 53.900000000000006 % done
# 54.1 % done
# 54.300000000000004 % done
# 54.400000000000006 % done
# 54.6 % done
# 54.800000000000004 % done
# 54.900000000000006 % done
# 55.1 % done
# 55.300000000000004 % done
# 55.400000000000006 % done
# 55.60000000000001 % done
# 55.800000000000004 % done
# 55.900000000000006 % done
# 56.10000000000001 % done
# 56.3 % done
# 56.39999999999999 % done
# 56.599999999999994 % done
# 56.8 % done
# 56.89999999999999 % done
# 57.099999999999994 % done
# 57.3 % done
# 57.4 % done
# 57.599999999999994 % done
# 57.8 % done
# 57.9 % done
# 58.099999999999994 % done
# 58.3 % done
# 58.4 % done
# 58.599999999999994 % done
# 58.8 % done
# 58.9 % done
# 59.099999999999994 % done
# 59.3 % done
# 59.4 % done
# 59.599999999999994 % done
# 59.8 % done
# 59.9 % done
# 60.099999999999994 % done
# 60.3 % done
# 60.4 % done
# 60.6 % done
# 60.8 % done
# 60.9 % done
# 61.1 % done
# 61.3 % done
# 61.4 % done
# 61.6 % done
# 61.8 % done
# 61.9 % done
# 62.1 % done
# 62.3 % done
# 62.4 % done
# 62.6 % done
# 62.8 % done
# 62.9 % done
# 63.1 % done
# 63.3 % done
# 63.4 % done
# 63.6 % done
# 63.800000000000004 % done
# 63.9 % done
# 64.1 % done
# 64.3 % done
# 64.4 % done
# 64.60000000000001 % done
# 64.8 % done
# 64.9 % done
# 65.10000000000001 % done
# 65.3 % done
# 65.4 % done
# 65.60000000000001 % done
# 65.8 % done
# 65.9 % done
# 66.10000000000001 % done
# 66.3 % done
# 66.4 % done
# 66.60000000000001 % done
# 66.8 % done
# 66.9 % done
# 67.10000000000001 % done
# 67.30000000000001 % done
# 67.4 % done
# 67.60000000000001 % done
# 67.80000000000001 % done
# 67.9 % done
# 68.10000000000001 % done
# 68.30000000000001 % done
# 68.4 % done
# 68.60000000000001 % done
# 68.8 % done
# 68.89999999999999 % done
# 69.1 % done
# 69.3 % done
# 69.39999999999999 % done
# 69.6 % done
# 69.8 % done
# 69.89999999999999 % done
# 70.1 % done
# 70.3 % done
# 70.5 % done
# 70.6 % done
# 70.8 % done
# 71.0 % done
# 71.1 % done
# 71.3 % done
# 71.5 % done
# 71.6 % done
# 71.8 % done
# 72.0 % done
# 72.1 % done
# 72.3 % done
# 72.5 % done
# 72.6 % done
# 72.8 % done
# 73.0 % done
# 73.1 % done
# 73.3 % done
# 73.5 % done
# 73.6 % done
# 73.8 % done
# 74.0 % done
# 74.1 % done
# 74.3 % done
# 74.5 % done
# 74.6 % done
# 74.8 % done
# 75.0 % done
# 75.1 % done
# 75.3 % done
# 75.5 % done
# 75.6 % done
# 75.8 % done
# 76.0 % done
# 76.1 % done
# 76.3 % done
# 76.5 % done
# 76.6 % done
# 76.8 % done
# 77.0 % done
# 77.10000000000001 % done
# 77.3 % done
# 77.5 % done
# 77.60000000000001 % done
# 77.8 % done
# 78.0 % done
# 78.10000000000001 % done
# 78.3 % done
# 78.5 % done
# 78.60000000000001 % done
# 78.8 % done
# 79.0 % done
# 79.10000000000001 % done
# 79.3 % done
# 79.5 % done
# 79.60000000000001 % done
# 79.80000000000001 % done
# 80.0 % done
# 80.10000000000001 % done
# 80.30000000000001 % done
# 80.5 % done
# 80.60000000000001 % done
# 80.80000000000001 % done
# 81.0 % done
# 81.10000000000001 % done
# 81.3 % done
# 81.5 % done
# 81.6 % done
# 81.8 % done
# 82.0 % done
# 82.1 % done
# 82.3 % done
# 82.5 % done
# 82.6 % done
# 82.8 % done
# 83.0 % done
# 83.1 % done
# 83.3 % done
# 83.5 % done
# 83.6 % done
# 83.8 % done
# 84.0 % done
# 84.1 % done
# 84.3 % done
# 84.5 % done
# 84.6 % done
# 84.8 % done
# 85.0 % done
# 85.1 % done
# 85.3 % done
# 85.5 % done
# 85.6 % done
# 85.8 % done
# 86.0 % done
# 86.1 % done
# 86.3 % done
# 86.5 % done
# 86.6 % done
# 86.8 % done
# 87.0 % done
# 87.1 % done
# 87.3 % done
# 87.5 % done
# 87.6 % done
# 87.8 % done
# 88.0 % done
# 88.1 % done
# 88.3 % done
# 88.5 % done
# 88.6 % done
# 88.8 % done
# 89.0 % done
# 89.1 % done
# 89.3 % done
# 89.5 % done
# 89.60000000000001 % done
# 89.8 % done
# 90.0 % done
# 90.2 % done
# 90.3 % done
# 90.5 % done
# 90.7 % done
# 90.8 % done
# 91.0 % done
# 91.2 % done
# 91.3 % done
# 91.5 % done
# 91.7 % done
# 91.8 % done
# 92.0 % done
# 92.2 % done
# 92.30000000000001 % done
# 92.5 % done
# 92.7 % done
# 92.80000000000001 % done
# 93.0 % done
# 93.2 % done
# 93.30000000000001 % done
# 93.5 % done
# 93.7 % done
# 93.8 % done
# 94.0 % done
# 94.19999999999999 % done
# 94.3 % done
# 94.5 % done
# 94.69999999999999 % done
# 94.8 % done
# 95.0 % done
# 95.19999999999999 % done
# 95.3 % done
# 95.5 % done
# 95.7 % done
# 95.8 % done
# 96.0 % done
# 96.2 % done
# 96.3 % done
# 96.5 % done
# 96.7 % done
# 96.8 % done
# 97.0 % done
# 97.2 % done
# 97.3 % done
# 97.5 % done
# 97.7 % done
# 97.8 % done
# 98.0 % done
# 98.2 % done
# 98.3 % done
# 98.5 % done
# 98.7 % done
# 98.8 % done
# 99.0 % done
# 99.2 % done
# 99.3 % done
# 99.5 % done
# 99.7 % done
# 99.8 % done
# 100.0 % done

# %%
atk_dice = widgets.IntSlider(
    value = 1.0,
    min = 1.0,
    max = 5.0,
    step = 1.0,
    description = 'Number of Attack Dice',
    continuous_update = False)

def_dice = widgets.IntSlider(
    value = 1.0,
    min = 1.0,
    max = 5.0,
    step = 1.0,
    description = 'Number of Defense Dice',
    continuous_update = False)

num_ev = widgets.IntSlider(
    value = 0.0,
    min = 0.0,
    max = 2.0,
    step = 1.0,
    description = 'Number of Evade Tokens',
    continuous_update = False)

tgt_lk = widgets.Checkbox(
    description = 'Target Lock',
    value = False)

atk_f = widgets.Checkbox(
    description = 'Attack Focus',
    value = False)

def_f = widgets.Checkbox(
    description = 'Defense Focus',
    value = False)

container1 = widgets.HBox(children = [atk_dice, atk_f, tgt_lk])
container2 = widgets.HBox(children = [def_dice, def_f, num_ev])

j = 1
row = df.iloc[j]
M = (row['M_atk_dice'])
mPhr = row.Phr
print(mPhr)
mhits = np.arange(M+1)
trace1 = go.Bar(x = mhits, y = mPhr, opacity= 0.8, name = 'pdf')
g = go.FigureWidget(data = [trace1], 
                    layout = go.Layout(
                        title = dict(text = 'PDF')
                    )
                   )


widgets.VBox([container1, container2, g])
# Out:
# [0.0, 1.0]
# VBox(children=(HBox(children=(IntSlider(value=1, continuous_update=False, description='Number of Attack Dice',…

# %%
# 'Phr', 'Ph', 'Pe', 'atk_tl', 'atk_f', 'def_f', 'def_num_ev', 'EV_res', 'atk_ev', 'def_ev', 'pe', 'ph'

def response(change):
    print(change)
    #     M = 10
#     x1 = np.arange(M+1)
#     y1 = x1
#     print(atk_dice.value)
#     return(x1, y1)
    filter_list = [i and j and k and l and m and n for i, j, k, l, m, n in
                    zip(df['M_atk_dice'] == atk_dice.value, 
                        df['N_def_dice'] == def_dice.value,
                        df['atk_tl'] == tgt_lk.value, 
                        df['atk_f'] == atk_f.value,
                        df['def_f'] == def_f.value,
                        df['def_num_ev'] == num_ev.value)]
    temp_df = df[filter_list]
    
    print(temp_df)
    M = temp_df['M_atk_dice']
    x1 = np.arange(int(M)+1)
    y1 = temp_df.Phr
    y1 = np.array(list(y1), dtype=np.float)[0]
    y1 = y1[::-1]
    
    print("M = ", M, "x1 = ", x1, "y1 = ", y1)
    
    with g.batch_update():
        g.data[0].x = x1
        g.data[0].y = y1
#         g.title.text = "test"
#         g.layout.barmode = 'overlay'
#     g.layout.xaxis.title = 'Delay in Minutes'
#         g.layout.yaxis.title = 'Number of Delays'

# %%
atk_dice.observe(response, names = "value", type = "change")
def_dice.observe(response, names = "value", type = "change")
tgt_lk.observe(response, names="value", type = "change")
atk_f.observe(response, names="value", type = "change")
def_f.observe(response, names="value", type = "change")
num_ev.observe(response, names="value", type = "change")

# %%
widgets.VBox([container1, container2, g])
# Out:
# VBox(children=(HBox(children=(IntSlider(value=1, continuous_update=False, description='Number of Attack Dice',…
# {'name': 'value', 'old': 1, 'new': 2, 'owner': IntSlider(value=2, continuous_update=False, description='Number of Attack Dice', max=5, min=1), 'type': 'change'}
#      M_atk_dice  N_def_dice                       Phr  Ph  Pe  atk_tl  atk_f  \
# 141           2           1  [0.1562, 0.4062, 0.4375] NaN NaN   False  False
#
#      def_f  def_num_ev  EV_res  atk_ev  def_ev              pe  \
# 141  False           0  0.7188     1.0   False  [0.375, 0.625]
#
#                     ph
# 141  [0.25, 0.5, 0.25]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     667                 if 'buffer_paths' in data:
#     668                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 669                 self.set_state(state)
#     670
#     671         # Handle a state request.
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     537                     from_json = self.trait_metadata(name, 'from_json',
#     538                                                     self._trait_from_json)
# --> 539                     self.set_trait(name, from_json(sync_data[name], self))
#     540
#     541     def send(self, content, buffers=None):
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     598                 # Send new state to front-end
#     599                 self.send_state(key=name)
# --> 600         super(Widget, self).notify_change(change)
#     601
#     602     def __repr__(self):
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# <ipython-input-3-219b59b07b06> in response(change)
#      21     x1 = np.arange(int(M)+1)
#      22     y1 = temp_df.Phr
# ---> 23     y1 = np.array(list(y1), dtype=np.float)[0].reverse()
#      24
#      25     print("M = ", M, "x1 = ", x1, "y1 = ", y1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'reverse'
# {'name': 'value', 'old': 2, 'new': 4, 'owner': IntSlider(value=4, continuous_update=False, description='Number of Attack Dice', max=5, min=1), 'type': 'change'}
#      M_atk_dice  N_def_dice                                       Phr  Ph  Pe  \
# 381           4           1  [0.0391, 0.1797, 0.3281, 0.2969, 0.1562] NaN NaN
#
#      atk_tl  atk_f  def_f  def_num_ev  EV_res  atk_ev  def_ev              pe  \
# 381   False  False  False           0  1.6484     2.0   False  [0.375, 0.625]
#
#                                       ph
# 381  [0.0625, 0.25, 0.375, 0.25, 0.0625]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     667                 if 'buffer_paths' in data:
#     668                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 669                 self.set_state(state)
#     670
#     671         # Handle a state request.
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     537                     from_json = self.trait_metadata(name, 'from_json',
#     538                                                     self._trait_from_json)
# --> 539                     self.set_trait(name, from_json(sync_data[name], self))
#     540
#     541     def send(self, content, buffers=None):
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     598                 # Send new state to front-end
#     599                 self.send_state(key=name)
# --> 600         super(Widget, self).notify_change(change)
#     601
#     602     def __repr__(self):
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# <ipython-input-3-219b59b07b06> in response(change)
#      21     x1 = np.arange(int(M)+1)
#      22     y1 = temp_df.Phr
# ---> 23     y1 = np.array(list(y1), dtype=np.float)[0].reverse()
#      24
#      25     print("M = ", M, "x1 = ", x1, "y1 = ", y1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'reverse'
